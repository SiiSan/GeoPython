# %%
ice_cream_rating = 9
sleeping_rating = 10

# %%
first_name = "Siiri"
last_name = "Sandberg"
my_name = "Siiri Sandberg"

# %%
ice_cream_rating / sleeping_rating
# Out:
# 0.9

# %%
happiness_rating = 0.9

# %%
part1= "My name is"

# %%
part2= "and I give eating ice cream a score of"

# %%
part3= "out of 10!"

# %%
print(part1, first_name, part2, ice_cream_rating, part3)
# Out:
# My name is Siiri and I give eating ice cream a score of 9 out of 10!

# %%
part4 = "I am"

# %%
part5 = "and my sleeping sleeping enjoyment rating is"

# %%
part6 = "/10!"

# %%
print(part4, my_name, part5, sleeping_rating, part6)
# Out:
# I am Siiri Sandberg and my sleeping sleeping enjoyment rating is 10 /10!

# %%
part7 = "Based on the factors above, my happiness rating is"

# %%
part8 = "out of 1, or 90%!"

# %%
print(part7, happiness_rating, part8)
# Out:
# Based on the factors above, my happiness rating is 0.9 out of 1, or 90%!
